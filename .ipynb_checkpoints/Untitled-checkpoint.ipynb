# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_json('./Data/data.json')
df.set_index('id', inplace=True)
df = df.round(2)
df.head(5)
# Out:
#     aggregated_rating  aggregated_rating_count  category   cover  \
# id
# 1               90.00                      1.0         0   90967
# 2               70.00                      1.0         0   96746
# 3               83.00                      3.0         0  129190
# 4               63.64                     17.0         0   96744
# 5                 NaN                      NaN         0   93899
#
#     first_release_date game_modes       genres                     name  \
# id
# 1         9.535968e+08        [1]  [5, 13, 31]  Thief II: The Metal Age
# 2         9.123840e+08        [1]     [13, 31]  Thief: The Dark Project
# 3         1.085443e+09        [1]  [5, 13, 31]    Thief: Deadly Shadows
# 4         1.393286e+09        [1]      [5, 31]                    Thief
# 5         9.141984e+08     [1, 3]         [12]            Baldur's Gate
#
#              platforms  rating  rating_count  \
# id
# 1                  [6]   88.29         109.0
# ...

# %%
df.isnull().sum()
# Out:
# aggregated_rating          348
# aggregated_rating_count    348
# category                     0
# cover                        0
# first_release_date           2
# game_modes                   0
# genres                       1
# name                         0
# platforms                    2
# rating                     168
# rating_count               168
# summary                     27
# total_rating               124
# total_rating_count         124
# dtype: int64
