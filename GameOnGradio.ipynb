# %%
import gradio as gr
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./Visual data/game_load_data.csv')
df.set_index("id", inplace=True)
df.head(5)
# Out:
#        cover                              name  \
# id
# 1    90967.0           Thief II: The Metal Age
# 2    96746.0           Thief: The Dark Project
# 5    93899.0                     Baldur's Gate
# 6    90896.0  Baldur's Gate II: Shadows of Amn
# 9   104633.0                 Jagged Alliance 2
#
#                                               summary  Release Year  \
# id
# 1   The ultimate thief is back! Tread softly as yo...          2000
# 2   Thief is a first-person stealth game that like...          1998
# 5   Baldur's Gate is a fantasy role-playing video ...          1998
# 6   Every World has conflict. Good and evil. Frien...          2000
# 9   A ruthless dictator has taken control of the t...          1999
#
#     Score Rating  Adventure  Arcade  Card & Board Game  Fighting  \
# id
# 1             89          1       0                  0         0
# 2             78          1       0                  0         0
# ...

# %%
recommend_df = pd.DataFrame(columns = ['Name', 'Release Year', 'Score Rating', 'Summary'])

# %%
def gradio_recommend(number, dropdown, sort, year, platform, score):
# Out:
# Running on local URL:  http://127.0.0.1:7860/
#
# To create a public link, set `share=True` in `launch()`.
#         <iframe
#             width="900"
#             height="500"
#             src="http://127.0.0.1:7860/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# (<fastapi.applications.FastAPI at 0x7f8af40e6e50>,
#  'http://127.0.0.1:7860/',
#  None)
